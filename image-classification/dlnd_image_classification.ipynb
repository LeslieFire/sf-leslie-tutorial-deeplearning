# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 10
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 10:
# Image - Min Value: 24 Max Value: 130
# Image - Shape: (32, 32, 3)
# Label - Label Id: 4 Name: deer

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    min_v = 0
    max_v = 255
    return (x - min_v) / (max_v - min_v)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer
encoder = None

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    global encoder
    if encoder is None:
        encoder = LabelBinarizer()
        encoder.fit(x)
    labels = encoder.transform(x).astype(np.float32)
    return labels


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper
import numpy as np

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %%
valid_features.shape, valid_labels.shape
# Out:
# ((5000, 32, 32, 3), (5000, 10))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, (None, image_shape[0], image_shape[1], image_shape[2]), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, (None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides, name="conv2d_maxpool", stdev=0.001):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    with tf.name_scope(name):
    
        x_shape = x_tensor.shape.as_list()
        weight = tf.Variable(tf.truncated_normal((conv_ksize[0], conv_ksize[1], x_shape[3], conv_num_outputs), stddev=stdev), name="W")
        bias = tf.Variable(tf.truncated_normal([conv_num_outputs], stddev=stdev), name="B")

        layer1 = tf.nn.conv2d(x_tensor, 
                              filter = weight, 
                              strides=[1,conv_strides[0], conv_strides[1], 1], 
                              padding="VALID" )
        layer1 = tf.nn.relu(layer1 + bias)
        
        tf.summary.histogram("weights", weight)
        tf.summary.histogram("biases", bias)
        tf.summary.histogram("activations", layer1)

        layer2 = tf.nn.max_pool(layer1, 
                                ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                                strides=[1, pool_strides[0], pool_strides[1], 1], 
                                padding="VALID")
    
        return layer2 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    x_shape = x_tensor.shape.as_list()
    dim = np.prod(x_shape[1:])
    
    return tf.reshape(x_tensor, [-1, dim])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs, name="fc", stdev=0.001):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    with tf.name_scope(name):
    # TODO: Implement Function
        x_shape = x_tensor.shape.as_list()
        weight = tf.Variable(tf.truncated_normal([x_shape[1], num_outputs], stddev=stdev), name="W")
        bias = tf.Variable(tf.truncated_normal([num_outputs], stddev=stdev), name="B")
        linear = tf.add(tf.matmul(x_tensor, weight), bias)
        activation = tf.nn.relu(linear)
        
#         tf.summary.histogram("weights", weight)
#         tf.summary.histogram("biases", bias)
#         tf.summary.histogram("activations", activation)
        return activation


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs, name="output", stdev=0.1):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    with tf.name_scope(name):
        # TODO: Implement Function
        x_shape = x_tensor.shape.as_list()
        weight = tf.Variable(tf.truncated_normal([x_shape[1], num_outputs], stddev=stdev), name="W")
        bias = tf.Variable(tf.truncated_normal([num_outputs], stddev=stdev), name="B")

        return tf.add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob, stdev = 0.001):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    c1s2 = conv2d_maxpool(x, 6, (5, 5), (1, 1), (2, 2), (2, 2), "conv2d_maxpool1", stdev)
    c3s4 = conv2d_maxpool(c1s2, 16, (5, 5), (1, 1), (2, 2), (2, 2), "conv2d_maxpool2", stdev)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    s4 = flatten(c3s4)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    c5 = fully_conn(s4, 120, "fc1", stdev)
    c5 = tf.nn.dropout(c5, keep_prob)
    
    f6 = fully_conn(c5, 84, "fc2", stdev)
    f6 = tf.nn.dropout(f6, keep_prob)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(f6, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

#tf.summary.image("input", x, 3)

# Model
logits = conv_net(x, keep_prob, normal_stddev)
# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
with tf.name_scope("xent"):
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))

    #tf.summary.scalar("cross_entropy", cost)

with tf.name_scope("train"):
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# Accuracy
with tf.name_scope("accuracy"):
    correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')
    
    #tf.summary.scalar("accuracy", accuracy)
tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network_summary(session, all_summary, keep_probability, feature_batch, label_batch):
    return session.run(all_summary, feed_dict = {x: feature_batch, y: label_batch, keep_prob: keep_probability})

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = session.run(cost, feed_dict = {x: feature_batch, y: label_batch, keep_prob: 1.0})
    valid_acc = session.run(accuracy, feed_dict = {x: valid_features, y: valid_labels, keep_prob: 1.0})
    print("Training Loss: {:>5.2f} Validation Accuracy: {:.2f}%".format(loss, valid_acc*100))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
def make_hparam_string(learning_rate, weight_stdev):
    return "lr_{},stdev_{}".format(learning_rate, weight_stdev)

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 128
keep_probability = 0.5
normal_stddev = 0.005
learning_rate = 0.001
stdevs = [1e-1, 3e-2, 5e-2, 1e-2, 5e-3, 3e-3, 1e-3, 5e-4, 3e-4, 1e-4, 5e-5, 3e-5, 1e-5, 5e-6, 3e-6, 1e-6]
learning_rates = [3e-3, 1e-3, 5e-4, 3e-4, 1e-4, 5e-4, 3e-5, 1e-5]

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
for learning_rate in learning_rates:
    for normal_stddev in stdevs:
        print("learning rate : {}, standard deviation : {}".format(learning_rate, normal_stddev) )
        with tf.Session() as sess:
            # Initializing the variables
            sess.run(tf.global_variables_initializer())

            # Training cycle
            i = 0
            for epoch in range(epochs):
                batch_i = 1
                for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size): 
                    train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
                print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
                print_stats(sess, batch_features, batch_labels, cost, accuracy)

                i += 1
                if (i % 5 == 0):
                    break
# Out:
# Checking the Training on a Single Batch...
# learning rate : 0.003, standard deviation : 0.1
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.28 Validation Accuracy: 10.14%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.23 Validation Accuracy: 17.42%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.21 Validation Accuracy: 20.24%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.20 Validation Accuracy: 23.12%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.21 Validation Accuracy: 23.32%
# learning rate : 0.003, standard deviation : 0.03
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.24 Validation Accuracy: 11.22%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.22 Validation Accuracy: 20.84%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.22 Validation Accuracy: 22.46%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.22 Validation Accuracy: 24.02%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.22 Validation Accuracy: 24.32%
# learning rate : 0.003, standard deviation : 0.05
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.29 Validation Accuracy: 9.96%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.23 Validation Accuracy: 18.18%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.21 Validation Accuracy: 27.20%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.20 Validation Accuracy: 29.24%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.15 Validation Accuracy: 29.34%
# learning rate : 0.003, standard deviation : 0.01
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.31 Validation Accuracy: 9.78%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 9.98%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.31 Validation Accuracy: 9.78%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 10.20%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 10.50%
# learning rate : 0.003, standard deviation : 0.005
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 9.44%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.29 Validation Accuracy: 14.14%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.25 Validation Accuracy: 15.94%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.22 Validation Accuracy: 19.18%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.23 Validation Accuracy: 19.66%
# learning rate : 0.003, standard deviation : 0.003
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 10.20%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 10.20%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 11.84%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.21 Validation Accuracy: 17.46%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.20 Validation Accuracy: 20.22%
# learning rate : 0.003, standard deviation : 0.001
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.31 Validation Accuracy: 10.50%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 12.02%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.28 Validation Accuracy: 14.18%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.26 Validation Accuracy: 14.90%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.26 Validation Accuracy: 17.04%
# learning rate : 0.003, standard deviation : 0.0005
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 9.84%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.23 Validation Accuracy: 19.98%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.19 Validation Accuracy: 21.32%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.19 Validation Accuracy: 22.56%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.18 Validation Accuracy: 23.64%
# learning rate : 0.003, standard deviation : 0.0003
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 11.34%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.25 Validation Accuracy: 13.36%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.21 Validation Accuracy: 21.22%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.19 Validation Accuracy: 22.24%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.17 Validation Accuracy: 23.76%
# learning rate : 0.003, standard deviation : 0.0001
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.30 Validation Accuracy: 15.48%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.23 Validation Accuracy: 20.90%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.18 Validation Accuracy: 22.20%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.20 Validation Accuracy: 22.94%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.19 Validation Accuracy: 24.00%
# learning rate : 0.003, standard deviation : 5e-05
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.29 Validation Accuracy: 9.38%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  2.23 Validation Accuracy: 20.62%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  2.22 Validation Accuracy: 21.94%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  2.23 Validation Accuracy: 23.66%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  2.22 Validation Accuracy: 24.22%
# learning rate : 0.003, standard deviation : 3e-05
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.26 Validation Accuracy: 15.96%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-bab42f510942> in <module>()
#      15                 batch_i = 1
#      16                 for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
# ---> 17                     train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
#      18                 print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
#      19                 print_stats(sess, batch_features, batch_labels, cost, accuracy)
#
# <ipython-input-24-1a7f7cccc68f> in train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch)
#       9     """
#      10     # TODO: Implement Function
# ---> 11     session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})
#      12
#      13
#
# /home/anaconda3/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/anaconda3/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/anaconda3/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/anaconda3/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/anaconda3/anaconda3/envs/dlnd-tf-lab/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Training Loss:  2.24 Validation Accuracy: 21.44%
# Epoch  1, CIFAR-10 Batch 2:  Training Loss:  2.02 Validation Accuracy: 25.20%
# Epoch  1, CIFAR-10 Batch 3:  Training Loss:  1.68 Validation Accuracy: 31.84%
# Epoch  1, CIFAR-10 Batch 4:  Training Loss:  1.74 Validation Accuracy: 36.38%
# Epoch  1, CIFAR-10 Batch 5:  Training Loss:  1.71 Validation Accuracy: 36.18%
# Epoch  2, CIFAR-10 Batch 1:  Training Loss:  1.93 Validation Accuracy: 39.00%
# Epoch  2, CIFAR-10 Batch 2:  Training Loss:  1.84 Validation Accuracy: 40.62%
# Epoch  2, CIFAR-10 Batch 3:  Training Loss:  1.34 Validation Accuracy: 41.38%
# Epoch  2, CIFAR-10 Batch 4:  Training Loss:  1.50 Validation Accuracy: 43.10%
# Epoch  2, CIFAR-10 Batch 5:  Training Loss:  1.53 Validation Accuracy: 43.46%
# Epoch  3, CIFAR-10 Batch 1:  Training Loss:  1.73 Validation Accuracy: 45.96%
# Epoch  3, CIFAR-10 Batch 2:  Training Loss:  1.65 Validation Accuracy: 45.88%
# Epoch  3, CIFAR-10 Batch 3:  Training Loss:  1.23 Validation Accuracy: 45.40%
# Epoch  3, CIFAR-10 Batch 4:  Training Loss:  1.41 Validation Accuracy: 47.86%
# Epoch  3, CIFAR-10 Batch 5:  Training Loss:  1.41 Validation Accuracy: 46.72%
# Epoch  4, CIFAR-10 Batch 1:  Training Loss:  1.65 Validation Accuracy: 48.78%
# Epoch  4, CIFAR-10 Batch 2:  Training Loss:  1.46 Validation Accuracy: 49.18%
# Epoch  4, CIFAR-10 Batch 3:  Training Loss:  1.13 Validation Accuracy: 46.72%
# Epoch  4, CIFAR-10 Batch 4:  Training Loss:  1.28 Validation Accuracy: 49.86%
# Epoch  4, CIFAR-10 Batch 5:  Training Loss:  1.40 Validation Accuracy: 48.22%
# Epoch  5, CIFAR-10 Batch 1:  Training Loss:  1.53 Validation Accuracy: 50.00%
# Epoch  5, CIFAR-10 Batch 2:  Training Loss:  1.37 Validation Accuracy: 50.48%
# Epoch  5, CIFAR-10 Batch 3:  Training Loss:  1.12 Validation Accuracy: 47.60%
# Epoch  5, CIFAR-10 Batch 4:  Training Loss:  1.31 Validation Accuracy: 51.10%
# Epoch  5, CIFAR-10 Batch 5:  Training Loss:  1.33 Validation Accuracy: 50.58%
# Epoch  6, CIFAR-10 Batch 1:  Training Loss:  1.43 Validation Accuracy: 51.42%
# Epoch  6, CIFAR-10 Batch 2:  Training Loss:  1.21 Validation Accuracy: 51.10%
# Epoch  6, CIFAR-10 Batch 3:  Training Loss:  1.07 Validation Accuracy: 51.08%
# Epoch  6, CIFAR-10 Batch 4:  Training Loss:  1.25 Validation Accuracy: 52.46%
# Epoch  6, CIFAR-10 Batch 5:  Training Loss:  1.30 Validation Accuracy: 52.40%
# Epoch  7, CIFAR-10 Batch 1:  Training Loss:  1.42 Validation Accuracy: 52.16%
# Epoch  7, CIFAR-10 Batch 2:  Training Loss:  1.24 Validation Accuracy: 52.28%
# Epoch  7, CIFAR-10 Batch 3:  Training Loss:  1.06 Validation Accuracy: 52.06%
# Epoch  7, CIFAR-10 Batch 4:  Training Loss:  1.20 Validation Accuracy: 53.22%
# Epoch  7, CIFAR-10 Batch 5:  Training Loss:  1.31 Validation Accuracy: 51.94%
# Epoch  8, CIFAR-10 Batch 1:  Training Loss:  1.36 Validation Accuracy: 53.36%
# Epoch  8, CIFAR-10 Batch 2:  Training Loss:  1.18 Validation Accuracy: 54.08%
# Epoch  8, CIFAR-10 Batch 3:  Training Loss:  1.04 Validation Accuracy: 51.86%
# Epoch  8, CIFAR-10 Batch 4:  Training Loss:  1.18 Validation Accuracy: 53.44%
# Epoch  8, CIFAR-10 Batch 5:  Training Loss:  1.20 Validation Accuracy: 53.34%
# Epoch  9, CIFAR-10 Batch 1:  Training Loss:  1.35 Validation Accuracy: 53.38%
# Epoch  9, CIFAR-10 Batch 2:  Training Loss:  1.19 Validation Accuracy: 51.78%
# Epoch  9, CIFAR-10 Batch 3:  Training Loss:  1.06 Validation Accuracy: 53.78%
# Epoch  9, CIFAR-10 Batch 4:  Training Loss:  1.19 Validation Accuracy: 53.26%
# Epoch  9, CIFAR-10 Batch 5:  Training Loss:  1.20 Validation Accuracy: 53.98%
# Epoch 10, CIFAR-10 Batch 1:  Training Loss:  1.25 Validation Accuracy: 55.10%
# Epoch 10, CIFAR-10 Batch 2:  Training Loss:  1.05 Validation Accuracy: 55.16%
# Epoch 10, CIFAR-10 Batch 3:  Training Loss:  1.02 Validation Accuracy: 53.40%
# Epoch 10, CIFAR-10 Batch 4:  Training Loss:  1.15 Validation Accuracy: 54.94%
# Epoch 10, CIFAR-10 Batch 5:  Training Loss:  1.14 Validation Accuracy: 54.72%
# Epoch 11, CIFAR-10 Batch 1:  Training Loss:  1.21 Validation Accuracy: 56.30%
# Epoch 11, CIFAR-10 Batch 2:  Training Loss:  1.02 Validation Accuracy: 55.42%
# Epoch 11, CIFAR-10 Batch 3:  Training Loss:  0.99 Validation Accuracy: 53.50%
# Epoch 11, CIFAR-10 Batch 4:  Training Loss:  1.11 Validation Accuracy: 55.24%
# Epoch 11, CIFAR-10 Batch 5:  Training Loss:  1.18 Validation Accuracy: 55.10%
# Epoch 12, CIFAR-10 Batch 1:  Training Loss:  1.15 Validation Accuracy: 56.34%
# Epoch 12, CIFAR-10 Batch 2:  Training Loss:  1.01 Validation Accuracy: 55.36%
# Epoch 12, CIFAR-10 Batch 3:  Training Loss:  0.96 Validation Accuracy: 55.30%
# Epoch 12, CIFAR-10 Batch 4:  Training Loss:  1.03 Validation Accuracy: 55.78%
# Epoch 12, CIFAR-10 Batch 5:  Training Loss:  1.12 Validation Accuracy: 55.74%
# Epoch 13, CIFAR-10 Batch 1:  Training Loss:  1.14 Validation Accuracy: 56.94%
# Epoch 13, CIFAR-10 Batch 2:  Training Loss:  0.98 Validation Accuracy: 55.66%
# Epoch 13, CIFAR-10 Batch 3:  Training Loss:  0.95 Validation Accuracy: 55.44%
# Epoch 13, CIFAR-10 Batch 4:  Training Loss:  0.99 Validation Accuracy: 56.20%
# Epoch 13, CIFAR-10 Batch 5:  Training Loss:  1.11 Validation Accuracy: 56.56%
# Epoch 14, CIFAR-10 Batch 1:  Training Loss:  1.10 Validation Accuracy: 56.84%
# Epoch 14, CIFAR-10 Batch 2:  Training Loss:  0.96 Validation Accuracy: 56.60%
# Epoch 14, CIFAR-10 Batch 3:  Training Loss:  0.92 Validation Accuracy: 55.86%
# Epoch 14, CIFAR-10 Batch 4:  Training Loss:  0.94 Validation Accuracy: 56.86%
# Epoch 14, CIFAR-10 Batch 5:  Training Loss:  1.09 Validation Accuracy: 55.66%
# Epoch 15, CIFAR-10 Batch 1:  Training Loss:  1.04 Validation Accuracy: 57.30%
# Epoch 15, CIFAR-10 Batch 2:  Training Loss:  0.94 Validation Accuracy: 57.26%
# Epoch 15, CIFAR-10 Batch 3:  Training Loss:  0.88 Validation Accuracy: 55.44%
# Epoch 15, CIFAR-10 Batch 4:  Training Loss:  0.92 Validation Accuracy: 56.76%
# Epoch 15, CIFAR-10 Batch 5:  Training Loss:  1.00 Validation Accuracy: 57.04%
# Epoch 16, CIFAR-10 Batch 1:  Training Loss:  1.01 Validation Accuracy: 57.74%
# Epoch 16, CIFAR-10 Batch 2:  Training Loss:  0.94 Validation Accuracy: 56.90%
# Epoch 16, CIFAR-10 Batch 3:  Training Loss:  0.89 Validation Accuracy: 56.98%
# Epoch 16, CIFAR-10 Batch 4:  Training Loss:  0.89 Validation Accuracy: 56.74%
# Epoch 16, CIFAR-10 Batch 5:  Training Loss:  1.01 Validation Accuracy: 56.20%
# Epoch 17, CIFAR-10 Batch 1:  Training Loss:  0.98 Validation Accuracy: 57.18%
# Epoch 17, CIFAR-10 Batch 2:  Training Loss:  0.89 Validation Accuracy: 58.10%
# Epoch 17, CIFAR-10 Batch 3:  Training Loss:  0.85 Validation Accuracy: 56.58%
# Epoch 17, CIFAR-10 Batch 4:  Training Loss:  0.86 Validation Accuracy: 57.86%
# Epoch 17, CIFAR-10 Batch 5:  Training Loss:  0.93 Validation Accuracy: 57.70%
# Epoch 18, CIFAR-10 Batch 1:  Training Loss:  0.95 Validation Accuracy: 57.54%
# Epoch 18, CIFAR-10 Batch 2:  Training Loss:  0.92 Validation Accuracy: 57.40%
# Epoch 18, CIFAR-10 Batch 3:  Training Loss:  0.89 Validation Accuracy: 57.76%
# Epoch 18, CIFAR-10 Batch 4:  Training Loss:  0.86 Validation Accuracy: 58.08%
# Epoch 18, CIFAR-10 Batch 5:  Training Loss:  0.88 Validation Accuracy: 58.06%
# Epoch 19, CIFAR-10 Batch 1:  Training Loss:  0.98 Validation Accuracy: 57.86%
# Epoch 19, CIFAR-10 Batch 2:  Training Loss:  0.90 Validation Accuracy: 58.04%
# Epoch 19, CIFAR-10 Batch 3:  Training Loss:  0.81 Validation Accuracy: 57.72%
# Epoch 19, CIFAR-10 Batch 4:  Training Loss:  0.89 Validation Accuracy: 57.02%
# Epoch 19, CIFAR-10 Batch 5:  Training Loss:  0.95 Validation Accuracy: 57.94%
# Epoch 20, CIFAR-10 Batch 1:  Training Loss:  0.94 Validation Accuracy: 57.92%
# Epoch 20, CIFAR-10 Batch 2:  Training Loss:  0.89 Validation Accuracy: 57.24%
# Epoch 20, CIFAR-10 Batch 3:  Training Loss:  0.85 Validation Accuracy: 57.66%
# Epoch 20, CIFAR-10 Batch 4:  Training Loss:  0.83 Validation Accuracy: 58.60%
# Epoch 20, CIFAR-10 Batch 5:  Training Loss:  0.94 Validation Accuracy: 58.10%
# Epoch 21, CIFAR-10 Batch 1:  Training Loss:  0.94 Validation Accuracy: 59.36%
# Epoch 21, CIFAR-10 Batch 2:  Training Loss:  0.84 Validation Accuracy: 58.74%
# Epoch 21, CIFAR-10 Batch 3:  Training Loss:  0.78 Validation Accuracy: 57.92%
# Epoch 21, CIFAR-10 Batch 4:  Training Loss:  0.87 Validation Accuracy: 57.84%
# Epoch 21, CIFAR-10 Batch 5:  Training Loss:  0.90 Validation Accuracy: 58.58%
# Epoch 22, CIFAR-10 Batch 1:  Training Loss:  0.89 Validation Accuracy: 58.28%
# Epoch 22, CIFAR-10 Batch 2:  Training Loss:  0.89 Validation Accuracy: 57.76%
# Epoch 22, CIFAR-10 Batch 3:  Training Loss:  0.83 Validation Accuracy: 58.50%
# Epoch 22, CIFAR-10 Batch 4:  Training Loss:  0.85 Validation Accuracy: 58.36%
# Epoch 22, CIFAR-10 Batch 5:  Training Loss:  0.84 Validation Accuracy: 59.34%
# Epoch 23, CIFAR-10 Batch 1:  Training Loss:  0.87 Validation Accuracy: 58.66%
# Epoch 23, CIFAR-10 Batch 2:  Training Loss:  0.83 Validation Accuracy: 58.40%
# Epoch 23, CIFAR-10 Batch 3:  Training Loss:  0.77 Validation Accuracy: 59.46%
# Epoch 23, CIFAR-10 Batch 4:  Training Loss:  0.83 Validation Accuracy: 57.38%
# Epoch 23, CIFAR-10 Batch 5:  Training Loss:  0.84 Validation Accuracy: 58.88%
# Epoch 24, CIFAR-10 Batch 1:  Training Loss:  0.87 Validation Accuracy: 58.16%
# Epoch 24, CIFAR-10 Batch 2:  Training Loss:  0.82 Validation Accuracy: 57.88%
# Epoch 24, CIFAR-10 Batch 3:  Training Loss:  0.74 Validation Accuracy: 58.72%
# Epoch 24, CIFAR-10 Batch 4:  Training Loss:  0.80 Validation Accuracy: 58.80%
# Epoch 24, CIFAR-10 Batch 5:  Training Loss:  0.85 Validation Accuracy: 59.32%
# Epoch 25, CIFAR-10 Batch 1:  Training Loss:  0.84 Validation Accuracy: 59.90%
# Epoch 25, CIFAR-10 Batch 2:  Training Loss:  0.80 Validation Accuracy: 59.04%
# Epoch 25, CIFAR-10 Batch 3:  Training Loss:  0.76 Validation Accuracy: 59.00%
# Epoch 25, CIFAR-10 Batch 4:  Training Loss:  0.74 Validation Accuracy: 59.20%
# Epoch 25, CIFAR-10 Batch 5:  Training Loss:  0.78 Validation Accuracy: 60.40%
# Epoch 26, CIFAR-10 Batch 1:  Training Loss:  0.85 Validation Accuracy: 59.10%
# Epoch 26, CIFAR-10 Batch 2:  Training Loss:  0.77 Validation Accuracy: 59.40%
# Epoch 26, CIFAR-10 Batch 3:  Training Loss:  0.73 Validation Accuracy: 59.22%
# Epoch 26, CIFAR-10 Batch 4:  Training Loss:  0.75 Validation Accuracy: 59.24%
# Epoch 26, CIFAR-10 Batch 5:  Training Loss:  0.77 Validation Accuracy: 59.38%
# Epoch 27, CIFAR-10 Batch 1:  Training Loss:  0.82 Validation Accuracy: 58.16%
# Epoch 27, CIFAR-10 Batch 2:  Training Loss:  0.79 Validation Accuracy: 58.18%
# Epoch 27, CIFAR-10 Batch 3:  Training Loss:  0.76 Validation Accuracy: 59.60%
# Epoch 27, CIFAR-10 Batch 4:  Training Loss:  0.77 Validation Accuracy: 58.62%
# Epoch 27, CIFAR-10 Batch 5:  Training Loss:  0.76 Validation Accuracy: 60.16%
# Epoch 28, CIFAR-10 Batch 1:  Training Loss:  0.77 Validation Accuracy: 58.70%
# Epoch 28, CIFAR-10 Batch 2:  Training Loss:  0.75 Validation Accuracy: 59.80%
# Epoch 28, CIFAR-10 Batch 3:  Training Loss:  0.74 Validation Accuracy: 59.30%
# Epoch 28, CIFAR-10 Batch 4:  Training Loss:  0.73 Validation Accuracy: 58.92%
# Epoch 28, CIFAR-10 Batch 5:  Training Loss:  0.77 Validation Accuracy: 59.66%
# Epoch 29, CIFAR-10 Batch 1:  Training Loss:  0.79 Validation Accuracy: 58.62%
# Epoch 29, CIFAR-10 Batch 2:  Training Loss:  0.75 Validation Accuracy: 59.96%
# Epoch 29, CIFAR-10 Batch 3:  Training Loss:  0.73 Validation Accuracy: 59.56%
# Epoch 29, CIFAR-10 Batch 4:  Training Loss:  0.74 Validation Accuracy: 58.96%
# Epoch 29, CIFAR-10 Batch 5:  Training Loss:  0.74 Validation Accuracy: 59.92%
# Epoch 30, CIFAR-10 Batch 1:  Training Loss:  0.76 Validation Accuracy: 58.24%
# Epoch 30, CIFAR-10 Batch 2:  Training Loss:  0.69 Validation Accuracy: 59.38%
# Epoch 30, CIFAR-10 Batch 3:  Training Loss:  0.67 Validation Accuracy: 60.26%
# Epoch 30, CIFAR-10 Batch 4:  Training Loss:  0.71 Validation Accuracy: 59.42%
# Epoch 30, CIFAR-10 Batch 5:  Training Loss:  0.74 Validation Accuracy: 60.58%
# Epoch 31, CIFAR-10 Batch 1:  Training Loss:  0.80 Validation Accuracy: 59.64%
# Epoch 31, CIFAR-10 Batch 2:  Training Loss:  0.67 Validation Accuracy: 60.08%
# Epoch 31, CIFAR-10 Batch 3:  Training Loss:  0.68 Validation Accuracy: 60.06%
# Epoch 31, CIFAR-10 Batch 4:  Training Loss:  0.74 Validation Accuracy: 58.42%
# Epoch 31, CIFAR-10 Batch 5:  Training Loss:  0.72 Validation Accuracy: 59.64%
# Epoch 32, CIFAR-10 Batch 1:  Training Loss:  0.74 Validation Accuracy: 59.16%
# Epoch 32, CIFAR-10 Batch 2:  Training Loss:  0.66 Validation Accuracy: 59.26%
# Epoch 32, CIFAR-10 Batch 3:  Training Loss:  0.65 Validation Accuracy: 60.52%
# Epoch 32, CIFAR-10 Batch 4:  Training Loss:  0.69 Validation Accuracy: 58.84%
# Epoch 32, CIFAR-10 Batch 5:  Training Loss:  0.69 Validation Accuracy: 59.22%
# Epoch 33, CIFAR-10 Batch 1:  Training Loss:  0.75 Validation Accuracy: 59.30%
# Epoch 33, CIFAR-10 Batch 2:  Training Loss:  0.66 Validation Accuracy: 58.88%
# Epoch 33, CIFAR-10 Batch 3:  Training Loss:  0.64 Validation Accuracy: 60.44%
# Epoch 33, CIFAR-10 Batch 4:  Training Loss:  0.67 Validation Accuracy: 60.12%
# Epoch 33, CIFAR-10 Batch 5:  Training Loss:  0.68 Validation Accuracy: 60.18%
# Epoch 34, CIFAR-10 Batch 1:  Training Loss:  0.72 Validation Accuracy: 60.14%
# Epoch 34, CIFAR-10 Batch 2:  Training Loss:  0.66 Validation Accuracy: 60.10%
# Epoch 34, CIFAR-10 Batch 3:  Training Loss:  0.65 Validation Accuracy: 60.20%
# Epoch 34, CIFAR-10 Batch 4:  Training Loss:  0.67 Validation Accuracy: 59.96%
# Epoch 34, CIFAR-10 Batch 5:  Training Loss:  0.69 Validation Accuracy: 59.62%
# Epoch 35, CIFAR-10 Batch 1:  Training Loss:  0.71 Validation Accuracy: 60.04%
# Epoch 35, CIFAR-10 Batch 2:  Training Loss:  0.64 Validation Accuracy: 59.58%
# Epoch 35, CIFAR-10 Batch 3:  Training Loss:  0.64 Validation Accuracy: 60.28%
# Epoch 35, CIFAR-10 Batch 4:  Training Loss:  0.66 Validation Accuracy: 60.14%
# Epoch 35, CIFAR-10 Batch 5:  Training Loss:  0.73 Validation Accuracy: 60.22%
# Epoch 36, CIFAR-10 Batch 1:  Training Loss:  0.72 Validation Accuracy: 59.50%
# Epoch 36, CIFAR-10 Batch 2:  Training Loss:  0.63 Validation Accuracy: 60.68%
# Epoch 36, CIFAR-10 Batch 3:  Training Loss:  0.61 Validation Accuracy: 61.22%
# Epoch 36, CIFAR-10 Batch 4:  Training Loss:  0.63 Validation Accuracy: 58.86%
# Epoch 36, CIFAR-10 Batch 5:  Training Loss:  0.68 Validation Accuracy: 60.70%
# Epoch 37, CIFAR-10 Batch 1:  Training Loss:  0.72 Validation Accuracy: 58.86%
# Epoch 37, CIFAR-10 Batch 2:  Training Loss:  0.63 Validation Accuracy: 60.58%
# Epoch 37, CIFAR-10 Batch 3:  Training Loss:  0.63 Validation Accuracy: 60.94%
# Epoch 37, CIFAR-10 Batch 4:  Training Loss:  0.62 Validation Accuracy: 60.52%
# Epoch 37, CIFAR-10 Batch 5:  Training Loss:  0.71 Validation Accuracy: 60.26%
# Epoch 38, CIFAR-10 Batch 1:  Training Loss:  0.74 Validation Accuracy: 59.58%
# Epoch 38, CIFAR-10 Batch 2:  Training Loss:  0.61 Validation Accuracy: 59.92%
# Epoch 38, CIFAR-10 Batch 3:  Training Loss:  0.63 Validation Accuracy: 60.88%
# Epoch 38, CIFAR-10 Batch 4:  Training Loss:  0.63 Validation Accuracy: 59.92%
# Epoch 38, CIFAR-10 Batch 5:  Training Loss:  0.64 Validation Accuracy: 59.84%
# Epoch 39, CIFAR-10 Batch 1:  Training Loss:  0.67 Validation Accuracy: 60.00%
# Epoch 39, CIFAR-10 Batch 2:  Training Loss:  0.60 Validation Accuracy: 60.88%
# Epoch 39, CIFAR-10 Batch 3:  Training Loss:  0.65 Validation Accuracy: 60.52%
# Epoch 39, CIFAR-10 Batch 4:  Training Loss:  0.62 Validation Accuracy: 58.68%
# Epoch 39, CIFAR-10 Batch 5:  Training Loss:  0.62 Validation Accuracy: 60.28%
# Epoch 40, CIFAR-10 Batch 1:  Training Loss:  0.66 Validation Accuracy: 60.44%
# Epoch 40, CIFAR-10 Batch 2:  Training Loss:  0.60 Validation Accuracy: 60.84%
# Epoch 40, CIFAR-10 Batch 3:  Training Loss:  0.59 Validation Accuracy: 61.20%
# Epoch 40, CIFAR-10 Batch 4:  Training Loss:  0.63 Validation Accuracy: 59.10%
# Epoch 40, CIFAR-10 Batch 5:  Training Loss:  0.64 Validation Accuracy: 59.52%
# Epoch 41, CIFAR-10 Batch 1:  Training Loss:  0.64 Validation Accuracy: 60.28%
# Epoch 41, CIFAR-10 Batch 2:  Training Loss:  0.60 Validation Accuracy: 60.28%
# Epoch 41, CIFAR-10 Batch 3:  Training Loss:  0.57 Validation Accuracy: 61.54%
# Epoch 41, CIFAR-10 Batch 4:  Training Loss:  0.62 Validation Accuracy: 59.14%
# Epoch 41, CIFAR-10 Batch 5:  Training Loss:  0.64 Validation Accuracy: 61.06%
# Epoch 42, CIFAR-10 Batch 1:  Training Loss:  0.63 Validation Accuracy: 59.64%
# Epoch 42, CIFAR-10 Batch 2:  Training Loss:  0.58 Validation Accuracy: 60.74%
# Epoch 42, CIFAR-10 Batch 3:  Training Loss:  0.61 Validation Accuracy: 59.74%
# Epoch 42, CIFAR-10 Batch 4:  Training Loss:  0.58 Validation Accuracy: 59.88%
# Epoch 42, CIFAR-10 Batch 5:  Training Loss:  0.64 Validation Accuracy: 60.18%
# Epoch 43, CIFAR-10 Batch 1:  Training Loss:  0.62 Validation Accuracy: 60.62%
# Epoch 43, CIFAR-10 Batch 2:  Training Loss:  0.57 Validation Accuracy: 59.98%
# Epoch 43, CIFAR-10 Batch 3:  Training Loss:  0.55 Validation Accuracy: 60.08%
# Epoch 43, CIFAR-10 Batch 4:  Training Loss:  0.64 Validation Accuracy: 59.26%
# Epoch 43, CIFAR-10 Batch 5:  Training Loss:  0.63 Validation Accuracy: 60.06%
# Epoch 44, CIFAR-10 Batch 1:  Training Loss:  0.67 Validation Accuracy: 60.30%
# Epoch 44, CIFAR-10 Batch 2:  Training Loss:  0.56 Validation Accuracy: 60.70%
# Epoch 44, CIFAR-10 Batch 3:  Training Loss:  0.60 Validation Accuracy: 60.52%
# Epoch 44, CIFAR-10 Batch 4:  Training Loss:  0.59 Validation Accuracy: 59.34%
# Epoch 44, CIFAR-10 Batch 5:  Training Loss:  0.58 Validation Accuracy: 60.32%
# Epoch 45, CIFAR-10 Batch 1:  Training Loss:  0.65 Validation Accuracy: 60.12%
# Epoch 45, CIFAR-10 Batch 2:  Training Loss:  0.56 Validation Accuracy: 59.46%
# Epoch 45, CIFAR-10 Batch 3:  Training Loss:  0.56 Validation Accuracy: 61.58%
# Epoch 45, CIFAR-10 Batch 4:  Training Loss:  0.57 Validation Accuracy: 59.50%
# Epoch 45, CIFAR-10 Batch 5:  Training Loss:  0.61 Validation Accuracy: 59.92%
# Epoch 46, CIFAR-10 Batch 1:  Training Loss:  0.63 Validation Accuracy: 60.20%
# Epoch 46, CIFAR-10 Batch 2:  Training Loss:  0.57 Validation Accuracy: 61.54%
# Epoch 46, CIFAR-10 Batch 3:  Training Loss:  0.59 Validation Accuracy: 61.44%
# Epoch 46, CIFAR-10 Batch 4:  Training Loss:  0.58 Validation Accuracy: 60.42%
# Epoch 46, CIFAR-10 Batch 5:  Training Loss:  0.63 Validation Accuracy: 60.30%
# Epoch 47, CIFAR-10 Batch 1:  Training Loss:  0.64 Validation Accuracy: 59.72%
# Epoch 47, CIFAR-10 Batch 2:  Training Loss:  0.57 Validation Accuracy: 60.12%
# Epoch 47, CIFAR-10 Batch 3:  Training Loss:  0.56 Validation Accuracy: 60.56%
# Epoch 47, CIFAR-10 Batch 4:  Training Loss:  0.60 Validation Accuracy: 59.74%
# Epoch 47, CIFAR-10 Batch 5:  Training Loss:  0.61 Validation Accuracy: 59.94%
# Epoch 48, CIFAR-10 Batch 1:  Training Loss:  0.58 Validation Accuracy: 60.64%
# Epoch 48, CIFAR-10 Batch 2:  Training Loss:  0.54 Validation Accuracy: 60.58%
# Epoch 48, CIFAR-10 Batch 3:  Training Loss:  0.56 Validation Accuracy: 60.88%
# Epoch 48, CIFAR-10 Batch 4:  Training Loss:  0.61 Validation Accuracy: 58.82%
# Epoch 48, CIFAR-10 Batch 5:  Training Loss:  0.61 Validation Accuracy: 61.10%
# Epoch 49, CIFAR-10 Batch 1:  Training Loss:  0.59 Validation Accuracy: 60.98%
# Epoch 49, CIFAR-10 Batch 2:  Training Loss:  0.54 Validation Accuracy: 60.28%
# Epoch 49, CIFAR-10 Batch 3:  Training Loss:  0.53 Validation Accuracy: 61.40%
# Epoch 49, CIFAR-10 Batch 4:  Training Loss:  0.55 Validation Accuracy: 60.22%
# Epoch 49, CIFAR-10 Batch 5:  Training Loss:  0.59 Validation Accuracy: 61.44%
# Epoch 50, CIFAR-10 Batch 1:  Training Loss:  0.61 Validation Accuracy: 60.04%
# Epoch 50, CIFAR-10 Batch 2:  Training Loss:  0.55 Validation Accuracy: 61.02%
# Epoch 50, CIFAR-10 Batch 3:  Training Loss:  0.55 Validation Accuracy: 60.90%
# Epoch 50, CIFAR-10 Batch 4:  Training Loss:  0.62 Validation Accuracy: 60.28%
# Epoch 50, CIFAR-10 Batch 5:  Training Loss:  0.58 Validation Accuracy: 60.26%

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy/accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6036392405063291

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
